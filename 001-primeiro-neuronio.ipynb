# %% [markdown]
# <a href="https://colab.research.google.com/github/bernardogoltz/rede-neural/blob/main/neuronio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# # Representação computacional análoga ao neurônio do sistema nervoso humano.
#
#
# 1.   Dendrito -> Recebe entradas.
# 3. Corpo -> Processamento das entradas.
# 2.   Axônio -> saída, depende da intensidade do sinal
#
#
#
# 1.   entradas -> os valores de x
# 3. Corpo -> g(x)
# 2.   Axônio -> f(x), ativada para dados valores de g
#
# neuronios portas logicas
#
# neuronios em que cada entrada tinha um peso
#
# problema xor
#
# backpropagation
#
# tensores - estruturas de dados (numeros N-DIMENSIONAIS, N natural) utilizadas por RNA's
#
# Função De Ativação Sigmoid

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def redeNeural(x1, x2, w1, w2 , b ):
    z = x1 * w1 + x2 + w2 + b 
    return sigmoide(z)

def sigmoide(x):
    return 1/(1+np.exp(-x))

# %%
w1 = np.random.randn()
w2 = np.random.randn()
b = np.random.randn()

# %%
redeNeural(3 , 1.5 , w1 , w2 , b)
# Out:
# 0.9832164318055855
